# %%
tamaño= input("Que tamaño desea pedir: ")
sabor= input("Ingresa el sabor que desea pedir: ")
cantidad= int(input("Ingresa la cantidad de helados que queres: "))
cobertura= input("Cual es la cobertura que desea?: ")

def pedidos_de_helado(Tamaño, Sabor, Cantidad, Cobertura):
    print(f"Preparando tu helado con las siguientes caracteristicas: Tamaño:{Tamaño}, Sabor:{Sabor}, Cantidad:{Cantidad}, Cobertura:{Cobertura}")
    print("Tu pedido de helado🍦 esta listo :)")

pedidos_de_helado(tamaño, sabor, cantidad, cobertura)
# Out:
# Preparando tu helado con las siguientes caracteristicas: Tamaño:Mediano, Sabor:Americana, Cantidad:2, Cobertura:Chocolate
# Tu pedido de helado🍦 esta listo :)
